# %% [markdown]
# # Use of PSD to represent data

# %% [markdown]
# - get PSD function + visualisation
# - import data and prepare dataFrame
# - get Train-test_sets
# - train AE - get predictions

# %%
import numpy as np
import os 
import librosa
import librosa.display
import soundfile as sf
import pandas as pd

from scipy import signal
import matplotlib.pyplot as plt

from ssqueezepy import cwt
from ssqueezepy.visuals import plot, imshow

# %%
def import_data(wav_name,channel=4):
    try:
        multi_channel_data, sr = sf.read(wav_name)
        if multi_channel_data.ndim <= 1:
            # ADD HERE A CONDITION TO READ MULTICHANNEL LENGTH AND REMOVE IF TOO SHORT
            return sr, multi_channel_data
        return sr, np.array(multi_channel_data)[:,channel]
    except ValueError:
        pass

# %%
def cwt_DF_Maker(user_path,data_path,filenum):
    your_path = user_path+data_path
    files = os.listdir(your_path)
    file = files[filenum]
    if os.path.isfile(os.path.join(your_path,file)):
        fs, audio = import_data(os.path.join(your_path,file))
        # Calculate continuous wavelet transform
        coef, freqs = pywt.cwt(x, np.arange(1, 50), 'morl', sampling_period=fs)
    return coef,freqs,file

# %%
names = ['fan']
IDs = ['id_00','id_02', 'id_04', 'id_06']
stati = ['normal', 'abnormal']
SNR = ['+6dB', '-6dB']

folder = '/MIMII/RawData/' + SNR[0] + '/' # fan/id_00/abnormal'
user_path = 'C:/Users/carbo/Documents/'
writer_path = 'C:/Users/carbo/Documents/MIMII/Data/' + SNR[0] +'/PSD/'

# %% [markdown]
# PSD pour data normale

# %%
ID = IDs[3]
status = stati[0]
name = names[0]

data_path = folder + name + '/' + ID + '/' + status


#### Multiple plots
plt.figure(1)

f_vec, Pxx, filename = cwt_DF_Maker(user_path,data_path,50)
# Show w.r.t. time and frequency
plt.figure(figsize=(5, 2))
plt.pcolor(t, freqs, coef)
plt.semilogy(f_vec, Pxx)
plt.xlabel('time [s]')
plt.ylabel('freq [Hz]')
plt.title('scalo ' + str(filename))
# Out:
# C:\Users\carbo\OneDrive\Documents\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\carbo\OneDrive\Documents\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\carbo\OneDrive\Documents\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\carbo\OneDrive\Documents\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
#
# KeyboardInterrupt

# %%
ID = IDs[3]
status = stati[1]
name = names[0]

data_path = folder + name + '/' + ID + '/' + status

#### Multiple plots
plt.figure(1)
plt.subplot(411)
f_vec, Pxx, filename = PSD_DF_Maker(user_path,data_path,50)
plt.semilogy(f_vec, Pxx)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.ylim([0.5e-9, 1e-6])
plt.title('PSD ' + str(filename))


plt.subplot(412)
f_vec, Pxx, filename = PSD_DF_Maker(user_path,data_path,100)
plt.semilogy(f_vec, Pxx)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.ylim([0.5e-9, 1e-6])
plt.title('PSD ' + str(filename))

plt.subplot(413)
f_vec, Pxx, filename = PSD_DF_Maker(user_path,data_path,150)
plt.semilogy(f_vec, Pxx)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.ylim([0.5e-9, 1e-6])
plt.title('PSD ' + str(filename))

plt.subplot(414)
f_vec, Pxx, filename = PSD_DF_Maker(user_path,data_path,200)
plt.semilogy(f_vec, Pxx)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.ylim([0.5e-9, 1e-6])
plt.title('PSD ' + str(filename))


plt.show()

# %% [markdown]
# ## Feature engineering
#
# Considering different features to interpret for the AE rather than the full PSD might be doable :
# - Mean value
# - Peaks frequency
# - Max peak amplitude
#
# Other than that, the PSD can be cut around 3000 Hz, the frequency content is not interesting above this threshold.

# %% [markdown]
# cutting PSD at 3000 Hz

# %%
PSD_cut = Pxx[f_vec < 3000]

# %%
PSD_cut.shape
# Out:
# (192,)

# %% [markdown]
# # Training of AE using PSD

# %% [markdown]
# - Gather all PSD onto a dataframe (cut at 3000 Hz)
# - Train an autoencoder

# %%
def PSD_DF_Maker(user_path,data_path):
    your_path = user_path+data_path
    files = os.listdir(your_path)
    
    PSD_list = [] 
    
    for index,file in enumerate(files):
        if os.path.isfile(os.path.join(your_path,file)):

            fs, audio = import_data(os.path.join(your_path,file))
            f_vec, PSD = signal.welch(audio, fs, nperseg=1024)
            PSD = PSD[f_vec < 3000]

            PSD_list.append(PSD)
    return pd.DataFrame(PSD_list)

# %%
def lossCalcMSE(model,data):
    reconstructions = model(tf.cast(data,float))
    return tf.keras.losses.mse(reconstructions,data)

lossValues = lossCalcMSE(autoencoder, test_set)

# %% [markdown]
# # __Main__ function

# %%
import sklearn
from sklearn import metrics
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
import tensorflow_probability as tfp
from tensorflow.keras import backend as K
import numpy as np
## import functions
import sys
sys.path.append("..")
from src import Train_test_sets_maker
from src import MinMaxNormalisation
from src import Visualize
from src import MIMII_AE

# %%
### Path files
names = ['fan']
stati = ['normal', 'abnormal']
SNR = ['+6dB', '-6dB']

folder = '/MIMII/RawData/' + SNR[0] + '/' # fan/id_00/abnormal'
user_path = 'C:/Users/carbo/Documents/'
writer_path = 'C:/Users/carbo/Documents/MIMII/Data/' + SNR[0] +'/PSD/'

### Parameters
IDs = ['id_00','id_02', 'id_04', 'id_06']

AUCs = []

for ID in IDs:

    # Get data
    ID = IDs[2]
    status = stati[0] # normal
    name = names[0]
    data_path = folder + name + '/' + ID + '/' + status
    df_PSD_normal = PSD_DF_Maker(user_path, data_path)

    status = stati[1] # abnormal
    data_path = folder + name + '/' + ID + '/' + status
    df_PSD_abnormal = PSD_DF_Maker(user_path, data_path)

    # Create datasets for training/evaluation
    train_set, test_set, test_labels = Train_test_sets_maker.fun(df_PSD_normal,df_PSD_abnormal)
    # Normalize
    MIN,MAX = MinMaxNormalisation.getMinMax(train_set)
    train_set = MinMaxNormalisation.fun(train_set,MIN,MAX)
    test_set = MinMaxNormalisation.fun(test_set,MIN,MAX)


    # Train algorithm
    autoencoder = MIMII_AE.fun(train_set.shape[1])
    history = autoencoder.fit(train_set, train_set, 
                              epochs=50, 
                              batch_size=512,
                              validation_data=(test_set,test_set),
                              validation_split = 0.1,
                              verbose = 1,
                              shuffle=True
                             )

    lossValues = lossCalcMSE(autoencoder, test_set)
    AUCs.append(metrics.roc_auc_score(~test_labels, lossValues))
# Out:
# Train & test sets created !
# Epoch 1/50
# 2/2 [==============================] - 1s 130ms/step - loss: 0.0078 - val_loss: 0.0115
# Epoch 2/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0072 - val_loss: 0.0110
# Epoch 3/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0068 - val_loss: 0.0106
# Epoch 4/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0065 - val_loss: 0.0101
# Epoch 5/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0061 - val_loss: 0.0096
# Epoch 6/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0057 - val_loss: 0.0090
# Epoch 7/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0053 - val_loss: 0.0083
# Epoch 8/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0048 - val_loss: 0.0076
# Epoch 9/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0043 - val_loss: 0.0069
# Epoch 10/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0038 - val_loss: 0.0063
# Epoch 11/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0034 - val_loss: 0.0058
# Epoch 12/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0030 - val_loss: 0.0053
# Epoch 13/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 14/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0023 - val_loss: 0.0044
# Epoch 15/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 16/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 17/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0014 - val_loss: 0.0037
# Epoch 18/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 19/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0010 - val_loss: 0.0034
# Epoch 20/50
# 2/2 [==============================] - 0s 24ms/step - loss: 8.6930e-04 - val_loss: 0.0033
# Epoch 21/50
# 2/2 [==============================] - 0s 23ms/step - loss: 7.3622e-04 - val_loss: 0.0033
# Epoch 22/50
# 2/2 [==============================] - 0s 24ms/step - loss: 6.3470e-04 - val_loss: 0.0033
# Epoch 23/50
# 2/2 [==============================] - 0s 22ms/step - loss: 5.6229e-04 - val_loss: 0.0033
# Epoch 24/50
# 2/2 [==============================] - 0s 23ms/step - loss: 5.1072e-04 - val_loss: 0.0033
# Epoch 25/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.7484e-04 - val_loss: 0.0033
# Epoch 26/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.5131e-04 - val_loss: 0.0033
# Epoch 27/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.3808e-04 - val_loss: 0.0033
# Epoch 28/50
# 2/2 [==============================] - 0s 23ms/step - loss: 4.3279e-04 - val_loss: 0.0033
# Epoch 29/50
# 2/2 [==============================] - 0s 23ms/step - loss: 4.3152e-04 - val_loss: 0.0033
# Epoch 30/50
# 2/2 [==============================] - 0s 23ms/step - loss: 4.3022e-04 - val_loss: 0.0033
# Epoch 31/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.2660e-04 - val_loss: 0.0033
# Epoch 32/50
# 2/2 [==============================] - 0s 25ms/step - loss: 4.2112e-04 - val_loss: 0.0033
# Epoch 33/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.1486e-04 - val_loss: 0.0033
# Epoch 34/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.0876e-04 - val_loss: 0.0034
# Epoch 35/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.0345e-04 - val_loss: 0.0034
# Epoch 36/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.9933e-04 - val_loss: 0.0033
# Epoch 37/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9674e-04 - val_loss: 0.0033
# Epoch 38/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9521e-04 - val_loss: 0.0033
# Epoch 39/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.9475e-04 - val_loss: 0.0033
# Epoch 40/50
# 2/2 [==============================] - 0s 25ms/step - loss: 3.9453e-04 - val_loss: 0.0033
# Epoch 41/50
# 2/2 [==============================] - 0s 23ms/step - loss: 3.9387e-04 - val_loss: 0.0033
# Epoch 42/50
# 2/2 [==============================] - 0s 27ms/step - loss: 3.9309e-04 - val_loss: 0.0033
# Epoch 43/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.9190e-04 - val_loss: 0.0032
# Epoch 44/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.9118e-04 - val_loss: 0.0032
# Epoch 45/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9052e-04 - val_loss: 0.0032
# Epoch 46/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9037e-04 - val_loss: 0.0032
# Epoch 47/50
# 2/2 [==============================] - 0s 22ms/step - loss: 3.9017e-04 - val_loss: 0.0032
# Epoch 48/50
# 2/2 [==============================] - 0s 23ms/step - loss: 3.9000e-04 - val_loss: 0.0032
# Epoch 49/50
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8983e-04 - val_loss: 0.0032
# Epoch 50/50
# 2/2 [==============================] - 0s 25ms/step - loss: 3.8948e-04 - val_loss: 0.0032
# Train & test sets created !
# Epoch 1/50
# 2/2 [==============================] - 1s 126ms/step - loss: 0.0075 - val_loss: 0.0114
# Epoch 2/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0071 - val_loss: 0.0110
# Epoch 3/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0068 - val_loss: 0.0106
# Epoch 4/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0065 - val_loss: 0.0101
# Epoch 5/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0062 - val_loss: 0.0096
# Epoch 6/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0058 - val_loss: 0.0090
# Epoch 7/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0054 - val_loss: 0.0084
# Epoch 8/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0049 - val_loss: 0.0078
# Epoch 9/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0045 - val_loss: 0.0071
# Epoch 10/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0040 - val_loss: 0.0065
# Epoch 11/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0036 - val_loss: 0.0060
# Epoch 12/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 13/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0027 - val_loss: 0.0050
# Epoch 14/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 15/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 16/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0039
# Epoch 17/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 18/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0010 - val_loss: 0.0036
# Epoch 19/50
# 2/2 [==============================] - 0s 24ms/step - loss: 8.3267e-04 - val_loss: 0.0035
# Epoch 20/50
# 2/2 [==============================] - 0s 23ms/step - loss: 7.0391e-04 - val_loss: 0.0035
# Epoch 21/50
# 2/2 [==============================] - 0s 25ms/step - loss: 6.1650e-04 - val_loss: 0.0035
# Epoch 22/50
# 2/2 [==============================] - 0s 29ms/step - loss: 5.5687e-04 - val_loss: 0.0034
# Epoch 23/50
# 2/2 [==============================] - 0s 24ms/step - loss: 5.1708e-04 - val_loss: 0.0034
# Epoch 24/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.9039e-04 - val_loss: 0.0034
# Epoch 25/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.7146e-04 - val_loss: 0.0034
# Epoch 26/50
# 2/2 [==============================] - 0s 25ms/step - loss: 4.5810e-04 - val_loss: 0.0033
# Epoch 27/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.4963e-04 - val_loss: 0.0033
# Epoch 28/50
# 2/2 [==============================] - 0s 25ms/step - loss: 4.4117e-04 - val_loss: 0.0033
# Epoch 29/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.3230e-04 - val_loss: 0.0033
# Epoch 30/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.2382e-04 - val_loss: 0.0033
# Epoch 31/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.1643e-04 - val_loss: 0.0033
# Epoch 32/50
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0982e-04 - val_loss: 0.0032
# Epoch 33/50
# 2/2 [==============================] - 0s 23ms/step - loss: 4.0416e-04 - val_loss: 0.0032
# Epoch 34/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9941e-04 - val_loss: 0.0032
# Epoch 35/50
# 2/2 [==============================] - 0s 25ms/step - loss: 3.9566e-04 - val_loss: 0.0033
# Epoch 36/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9300e-04 - val_loss: 0.0033
# Epoch 37/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9136e-04 - val_loss: 0.0032
# Epoch 38/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.9039e-04 - val_loss: 0.0032
# Epoch 39/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8995e-04 - val_loss: 0.0032
# Epoch 40/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8930e-04 - val_loss: 0.0032
# Epoch 41/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8856e-04 - val_loss: 0.0032
# Epoch 42/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8751e-04 - val_loss: 0.0032
# Epoch 43/50
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8651e-04 - val_loss: 0.0032
# Epoch 44/50
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8557e-04 - val_loss: 0.0032
# Epoch 45/50
# 2/2 [==============================] - 0s 25ms/step - loss: 3.8474e-04 - val_loss: 0.0032
# Epoch 46/50
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8403e-04 - val_loss: 0.0032
# Epoch 47/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8362e-04 - val_loss: 0.0032
# Epoch 48/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8333e-04 - val_loss: 0.0032
# Epoch 49/50
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8299e-04 - val_loss: 0.0032
# Epoch 50/50
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8279e-04 - val_loss: 0.0032
# Train & test sets created !
# Epoch 1/50
# 2/2 [==============================] - 1s 127ms/step - loss: 0.0086 - val_loss: 0.0131
# Epoch 2/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0083 - val_loss: 0.0128
# Epoch 3/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0079 - val_loss: 0.0123
# Epoch 4/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0076 - val_loss: 0.0118
# Epoch 5/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0071 - val_loss: 0.0111
# Epoch 6/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0066 - val_loss: 0.0104
# Epoch 7/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0060 - val_loss: 0.0095
# Epoch 8/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0053 - val_loss: 0.0086
# Epoch 9/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0046 - val_loss: 0.0076
# Epoch 10/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0039 - val_loss: 0.0066
# Epoch 11/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0032 - val_loss: 0.0057
# Epoch 12/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0026 - val_loss: 0.0050
# Epoch 13/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 14/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 15/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 16/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 0.0038
# Epoch 17/50
# 2/2 [==============================] - 0s 26ms/step - loss: 9.2943e-04 - val_loss: 0.0037
# Epoch 18/50
# 2/2 [==============================] - 0s 24ms/step - loss: 8.1941e-04 - val_loss: 0.0037
# Epoch 19/50
# 2/2 [==============================] - 0s 24ms/step - loss: 7.3835e-04 - val_loss: 0.0037
# Epoch 20/50
# 2/2 [==============================] - 0s 24ms/step - loss: 6.7987e-04 - val_loss: 0.0037
# Epoch 21/50
# 2/2 [==============================] - 0s 26ms/step - loss: 6.3580e-04 - val_loss: 0.0037
# Epoch 22/50
# 2/2 [==============================] - 0s 26ms/step - loss: 6.0108e-04 - val_loss: 0.0037
# Epoch 23/50
# 2/2 [==============================] - 0s 23ms/step - loss: 5.7242e-04 - val_loss: 0.0038
# Epoch 24/50
# 2/2 [==============================] - 0s 22ms/step - loss: 5.4610e-04 - val_loss: 0.0038
# Epoch 25/50
# 2/2 [==============================] - 0s 26ms/step - loss: 5.2134e-04 - val_loss: 0.0038
# Epoch 26/50
# 2/2 [==============================] - 0s 29ms/step - loss: 5.0103e-04 - val_loss: 0.0038
# Epoch 27/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.8634e-04 - val_loss: 0.0038
# Epoch 28/50
# 2/2 [==============================] - 0s 25ms/step - loss: 4.7758e-04 - val_loss: 0.0039
# Epoch 29/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.7214e-04 - val_loss: 0.0039
# Epoch 30/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.6785e-04 - val_loss: 0.0039
# Epoch 31/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.6391e-04 - val_loss: 0.0038
# Epoch 32/50
# 2/2 [==============================] - 0s 25ms/step - loss: 4.6075e-04 - val_loss: 0.0038
# Epoch 33/50
# 2/2 [==============================] - 0s 25ms/step - loss: 4.5802e-04 - val_loss: 0.0038
# Epoch 34/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.5553e-04 - val_loss: 0.0038
# Epoch 35/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.5292e-04 - val_loss: 0.0038
# Epoch 36/50
# 2/2 [==============================] - 0s 23ms/step - loss: 4.5056e-04 - val_loss: 0.0038
# Epoch 37/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.4888e-04 - val_loss: 0.0038
# Epoch 38/50
# 2/2 [==============================] - 0s 30ms/step - loss: 4.4717e-04 - val_loss: 0.0038
# Epoch 39/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.4581e-04 - val_loss: 0.0038
# Epoch 40/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.4454e-04 - val_loss: 0.0037
# Epoch 41/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.4357e-04 - val_loss: 0.0037
# Epoch 42/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.4274e-04 - val_loss: 0.0037
# Epoch 43/50
# 2/2 [==============================] - 0s 27ms/step - loss: 4.4213e-04 - val_loss: 0.0037
# Epoch 44/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.4171e-04 - val_loss: 0.0037
# Epoch 45/50
# 2/2 [==============================] - 0s 25ms/step - loss: 4.4132e-04 - val_loss: 0.0037
# Epoch 46/50
# 2/2 [==============================] - 0s 24ms/step - loss: 4.4093e-04 - val_loss: 0.0037
# Epoch 47/50
# 2/2 [==============================] - 0s 26ms/step - loss: 4.4050e-04 - val_loss: 0.0037
# Epoch 48/50
# 2/2 [==============================] - 0s 30ms/step - loss: 4.4009e-04 - val_loss: 0.0037
# Epoch 49/50
# 2/2 [==============================] - 0s 28ms/step - loss: 4.3961e-04 - val_loss: 0.0037
# Epoch 50/50
# 2/2 [==============================] - 0s 29ms/step - loss: 4.3915e-04 - val_loss: 0.0037
# Train & test sets created !
# Epoch 1/50
# 2/2 [==============================] - 1s 143ms/step - loss: 0.0074 - val_loss: 0.0112
# Epoch 2/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0071 - val_loss: 0.0109
# Epoch 3/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0068 - val_loss: 0.0104
# Epoch 4/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0064 - val_loss: 0.0099
# Epoch 5/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0060 - val_loss: 0.0093
# Epoch 6/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0055 - val_loss: 0.0086
# Epoch 7/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0050 - val_loss: 0.0080
# Epoch 8/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0045 - val_loss: 0.0072
# Epoch 9/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0039 - val_loss: 0.0065
# Epoch 10/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0034 - val_loss: 0.0058
# Epoch 11/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 12/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 13/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 14/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 15/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0037
# Epoch 16/50
# 2/2 [==============================] - 0s 22ms/step - loss: 9.4044e-04 - val_loss: 0.0035
# Epoch 17/50
# 2/2 [==============================] - 0s 23ms/step - loss: 7.8572e-04 - val_loss: 0.0035
# Epoch 18/50
# 2/2 [==============================] - 0s 22ms/step - loss: 6.8384e-04 - val_loss: 0.0034
# Epoch 19/50
# 2/2 [==============================] - 0s 22ms/step - loss: 6.1942e-04 - val_loss: 0.0034
# Epoch 20/50
# 2/2 [==============================] - 0s 21ms/step - loss: 5.7433e-04 - val_loss: 0.0034
# Epoch 21/50
# 2/2 [==============================] - 0s 23ms/step - loss: 5.4277e-04 - val_loss: 0.0034
# Epoch 22/50
# 2/2 [==============================] - 0s 21ms/step - loss: 5.2163e-04 - val_loss: 0.0034
# Epoch 23/50
# 2/2 [==============================] - 0s 23ms/step - loss: 5.0489e-04 - val_loss: 0.0034
# Epoch 24/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.8989e-04 - val_loss: 0.0033
# Epoch 25/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.7703e-04 - val_loss: 0.0033
# Epoch 26/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.6715e-04 - val_loss: 0.0033
# Epoch 27/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.5989e-04 - val_loss: 0.0033
# Epoch 28/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.5355e-04 - val_loss: 0.0033
# Epoch 29/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.4753e-04 - val_loss: 0.0033
# Epoch 30/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.4180e-04 - val_loss: 0.0032
# Epoch 31/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.3722e-04 - val_loss: 0.0032
# Epoch 32/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.3330e-04 - val_loss: 0.0032
# Epoch 33/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2946e-04 - val_loss: 0.0032
# Epoch 34/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.2603e-04 - val_loss: 0.0032
# Epoch 35/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2342e-04 - val_loss: 0.0032
# Epoch 36/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.2173e-04 - val_loss: 0.0032
# Epoch 37/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2102e-04 - val_loss: 0.0032
# Epoch 38/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2048e-04 - val_loss: 0.0032
# Epoch 39/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1991e-04 - val_loss: 0.0032
# Epoch 40/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.1913e-04 - val_loss: 0.0032
# Epoch 41/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1825e-04 - val_loss: 0.0032
# Epoch 42/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1739e-04 - val_loss: 0.0032
# Epoch 43/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1684e-04 - val_loss: 0.0032
# Epoch 44/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1640e-04 - val_loss: 0.0032
# Epoch 45/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1599e-04 - val_loss: 0.0032
# Epoch 46/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.1560e-04 - val_loss: 0.0032
# Epoch 47/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.1526e-04 - val_loss: 0.0032
# Epoch 48/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1489e-04 - val_loss: 0.0032
# Epoch 49/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.1449e-04 - val_loss: 0.0032
# Epoch 50/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1420e-04 - val_loss: 0.0032

# %% [markdown]
# # Conclusion

# %% [markdown]
# The AUCs obtained with the PSD shows that it could be used to detect anomaly in the case of the fan: all IDs have > 0.98 as AUC

# %%
import pandas as pd
df_MIMII = pd.DataFrame(([0.75, 0.99, 0.92, 0.99],AUCs), columns = ['00','02', '04', '06']) 
df_MIMII
# Out:
#          00        02        04        06
# 0  0.750000  0.990000  0.920000  0.990000
# 1  0.988175  0.987779  0.986937  0.993245

# %%
np.mean(AUCs)
# Out:
# 0.9890342185229224
